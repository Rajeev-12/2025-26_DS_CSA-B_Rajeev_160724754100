# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/sorting_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#selection sort
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter the elments {i+1}")))
print("original array",arr)
for i in range(n-1):
  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
    arr[i],arr[min_index]=arr[min_index],arr[i]
print("soreted array",arr)
# Out:
# enter the number of elements3
# enter the elments 11
# enter the elments 212
# enter the elments 30
# original array [1, 12, 0]
# soreted array [0, 1, 12]

# %%
#bubble sort
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter element{i+1}:")))
print("\n original array:",arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("sorted array:",arr)
# Out:
# enter the number of elements4
# enter element1:12
# enter element2:32
# enter element3:6
# enter element4:6
#
#  original array: [12, 32, 6, 6]
# sorted array: [6, 6, 12, 32]
