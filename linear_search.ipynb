# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/linear_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#linear search
n=int(input("enter the number of elements:"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter the element {i+1}:")))
key=int(input("enter the elemnet to search:"))
found=False
for i in range(n):
  if arr[i]==key:
    print(f"element {key} found at position {i+1}")
    found=True
    break
if not found:
  print("elemnet {key} not found")
# Out:
# enter the number of elements:5
# enter the element 1:3
# enter the element 2:1
# enter the element 3:4
# enter the element 4:5
# enter the element 5:6
# enter the elemnet to search:4
# element 4 found at position 3
