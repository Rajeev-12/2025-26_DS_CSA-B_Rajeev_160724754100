# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/week-4/SQLite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect("example.db")

# Create a cursor object
cursor = conn.cursor()

# Creation of  Table
cursor.execute("""
CREATE TABLE IF NOT EXISTS users (
    id INTEGER PRIMARY KEY AUTOINCREMENT,
    name TEXT NOT NULL,
    age INTEGER,
    email TEXT UNIQUE
)
""")
print("Table created successfully.")

# Insert Data
cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)",
               ("Alice", 25, "alice@example.com"))

cursor.execute("INSERT INTO users (name, age, email) VALUES (?, ?, ?)",
               ("Bob", 30, "bob@example.com"))

conn.commit()
print("Data inserted successfully.")

# Read Data
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

print("\nUsers in database:")
for row in rows:
    print(row)

# Update Data
cursor.execute("UPDATE users SET age = ? WHERE name = ?", (28, "Alice"))
conn.commit()
print("\nRecord updated successfully.")

# Delete Data
cursor.execute("DELETE FROM users WHERE name = ?", ("Bob",))
conn.commit()
print("Record deleted successfully.")

# Display Data
cursor.execute("SELECT * FROM users")
rows = cursor.fetchall()

print("\nFinal data:")
for row in rows:
    print(row)

#close
conn.close()
print("\nDatabase connection closed.")
# Out:
# Table created successfully.
# Data inserted successfully.
#
# Users in database:
# (1, 'Alice', 25, 'alice@example.com')
# (2, 'Bob', 30, 'bob@example.com')
#
# Record updated successfully.
# Record deleted successfully.
#
# Final data:
# (1, 'Alice', 28, 'alice@example.com')
#
# Database connection closed.
