# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/week-4/EDAoperations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data=[10,12,27,18,20,22,25,30,35,40]
df=pd.DataFrame(data,columns=['values'])
print("Dataset:")
print(df)
print("\nSummary statistics:")
print(df.describe())
print("\nVariance:",np.var(data))
print("\nStandard deviation:",np.std(data))
plt.hist(data)
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Data Distribution')
plt.show()
mean_value=np.mean(data)
median_value=np.median(data)
mode_value = df['values'].mode()
print("\nInference:")
print("Mean:",mean_value)
print("Median:",median_value)
if len(mode_value) == 1:
    print("Mode:", mode_value[0])
else:
    print("Mode:", list(mode_value))
if mean_value>median_value:
    print("The distribution is positively skewed.")
elif mean_value<median_value:
    print("The distribution is negatively skewed.")
else:
    print("The distribution is symmetric.")
# Out:
# Dataset:
#    values
# 0      10
# 1      12
# 2      27
# 3      18
# 4      20
# 5      22
# 6      25
# 7      30
# 8      35
# 9      40
#
# Summary statistics:
#          values
# count  10.00000
# mean   23.90000
# std     9.53881
# min    10.00000
# 25%    18.50000
# 50%    23.50000
# 75%    29.25000
# max    40.00000
#
# Variance: 81.89
#
# Standard deviation: 9.04930936591296
# Inference:
# Mean: 23.9
# Median: 23.5
# Mode: [10, 12, 18, 20, 22, 25, 27, 30, 35, 40]
# The distribution is positively skewed.
