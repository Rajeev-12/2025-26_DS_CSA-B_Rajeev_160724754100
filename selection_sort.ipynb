# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/selection_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bubble sort
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter element{i+1}:")))
print("\n original array:",arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("sorted array:",arr)
# Out:
# enter the number of elements4
# enter element1:12
# enter element2:32
# enter element3:6
# enter element4:6
#
#  original array: [12, 32, 6, 6]
# sorted array: [6, 6, 12, 32]

# %%
#selection sort
n=int(input("enter the number of elements"))
arr=[]
for i in range(n):
  arr.append(int(input(f"enter the elments {i+1}:")))
print("original array",arr)
for i in range(n-1):
  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
  arr[i],arr[min_index]=arr[min_index],arr[i]
print("sorted array",arr)
# Out:
# enter the number of elements5
# enter the elments 1:2
# enter the elments 2:5
# enter the elments 3:4
# enter the elments 4:3
# enter the elments 5:8
# original array [2, 5, 4, 3, 8]
# sorted array [2, 3, 4, 5, 8]
