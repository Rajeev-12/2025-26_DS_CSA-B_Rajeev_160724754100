# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajeev-12/2025-26_DS_CSA-B_Rajeev_160724754100/blob/main/list_operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
list=[1,2,3,4,5]
print(list)
# Out:
# [1, 2, 3, 4, 5]

# %%
# Accessing elements
lst = [10, 20, 30, 40]
print("First element:", lst[0])
print("Last element:", lst[-1])
# Adding elements
# Out:
# First element: 10
# Last element: 40

# %%
#Adding elements
lst = [10, 20, 30, 40]
lst.append(50)
print("After append:", lst)
lst.insert(2, 25)
print("After insert:", lst)
lst.extend([60, 70])
print("After extend:", lst)
# Out:
# After append: [10, 20, 30, 40, 50]
# After insert: [10, 20, 25, 30, 40, 50]
# After extend: [10, 20, 25, 30, 40, 50, 60, 70]

# %%
# Updating element
lst = [10, 20, 30, 40]
lst[0] = 100
print("After updating:", lst)
# Out:
# After updating: [100, 20, 30, 40]

# %%
# Removing elements
lst = [10, 20, 30, 40]
lst.remove(30)
print("After remove:", lst)
lst.pop()
print("After pop:", lst)
lst.pop(1)
print("After pop at index 1:", lst)
# Out:
# After remove: [10, 20, 40]
# After pop: [10, 20]
# After pop at index 1: [10]

# %%
# Searching
lst = [10, 20, 30, 40]
print("Index of 30:", lst.index(30))
print("Count of 20:", lst.count(20))
# Out:
# Index of 30: 2
# Count of 20: 1

# %%
# Looping
lst = [10, 20, 30, 40]
print("Elements in list:")
for item in lst:
    print(item)
# Out:
# Elements in list:
# 10
# 20
# 30
# 40

# %%
# Clearing list
lst = [10, 20, 30, 40]
lst.clear()
print("After clear:", lst)
# Out:
# After clear: []
